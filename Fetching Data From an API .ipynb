# %%
import pandas as pd
import requests

# %%
dt = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
dt.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
#   'original_title': 'The Godfather',
#   'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#   'popularity': 107.242,
#   'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#   'release_date': '1972-03-14',
#   'title': 'The Godfather',
#   'video': False,
#   'vote_average': 8.7,
#   'vote_count': 17604},
#  {'adult': False,
#   'backdrop_path': '/wPU78OPN4BYEgWYdXyg0phMee64.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
# ...

# %%
temp_df = pd.DataFrame(dt.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df = pd.DataFrame()

# %%
for i in range(1,500):
    dt = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(dt.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index=True)

# %%
df

# %%
df.to_csv('movies.csv')

# %%
import pandas as pd
import requests

# %%
import requests

url = "https://covid-193.p.rapidapi.com/countries"

headers = {
"X-RapidAPI-Key": "7c97880d88msh385904ea8bbf2efp1265a2jsn984f1daf83a4",
"X-RapidAPI-Host": "covid-193.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {"get":"countries","parameters":[],"errors":[],"results":231,"response":["Afghanistan","Albania","Algeria","Andorra","Angola","Anguilla","Antigua-and-Barbuda","Argentina","Armenia","Aruba","Australia","Austria","Azerbaijan","Bahamas","Bahrain","Bangladesh","Barbados","Belarus","Belgium","Belize","Benin","Bermuda","Bhutan","Bolivia","Bosnia-and-Herzegovina","Botswana","Brazil","British-Virgin-Islands","Brunei","Bulgaria","Burkina-Faso","Burundi","Cabo-Verde","Cambodia","Cameroon","Canada","CAR","Caribbean-Netherlands","Cayman-Islands","Chad","Channel-Islands","Chile","China","Colombia","Comoros","Congo","Cook-Islands","Costa-Rica","Croatia","Cuba","Cura&ccedil;ao","Cyprus","Czechia","Denmark","Diamond-Princess","Djibouti","Dominica","Dominican-Republic","DPRK","DRC","Ecuador","Egypt","El-Salvador","Equatorial-Guinea","Eritrea","Estonia","Eswatini","Ethiopia","Faeroe-Islands","Falkland-Islands","Fiji","Finland","France","French-Guiana","French-Polynesia","Gabon","Gambia","Georgia","Ger
# ...

# %%
df = pd.DataFrame(response.json()['countries']).count()
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df = pd.DataFrame(response.json()['countries']).count()
#       2 df
#
# KeyError: 'countries'

# %%
response.json()['countries']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 response.json()['countries']
#
# KeyError: 'countries'

# %%
import requests

url = "https://ski-resort-forecast.p.rapidapi.com/Jackson%20Hole/forecast"

querystring = {"units":"i","el":"top"}

headers = {
	"X-RapidAPI-Key": "7c97880d88msh385904ea8bbf2efp1265a2jsn984f1daf83a4",
	"X-RapidAPI-Host": "ski-resort-forecast.p.rapidapi.com"
}

api_url = requests.request("GET", url, headers=headers, params=querystring)

print(api_url.text)
# Out:
# {"forecast5Day":[{"dayOfWeek":"thursday","am":{"summary":"clear","windSpeed":"10mph","windDirection":"N","snow":"0in","rain":"0in","maxTemp":"5°F","minTemp":"5°F","windChill":"-9°F","humidity":"58%","freezeLevel":"0ft"},"pm":{"summary":"some clouds","windSpeed":"5mph","windDirection":"N","snow":"0in","rain":"0in","maxTemp":"9°F","minTemp":"7°F","windChill":"-4°F","humidity":"75%","freezeLevel":"4800ft"},"night":{"summary":"clear","windSpeed":"0mph","windDirection":"ESE","snow":"0in","rain":"0in","maxTemp":"9°F","minTemp":"7°F","windChill":"7°F","humidity":"74%","freezeLevel":"0ft"}},{"dayOfWeek":"friday","am":{"summary":"clear","windSpeed":"5mph","windDirection":"N","snow":"0in","rain":"0in","maxTemp":"10°F","minTemp":"9°F","windChill":"1°F","humidity":"40%","freezeLevel":"0ft"},"pm":{"summary":"clear","windSpeed":"5mph","windDirection":"NW","snow":"0in","rain":"0in","maxTemp":"12°F","minTemp":"10°F","windChill":"10°F","humidity":"62%","freezeLevel":"4900ft"},"night":{"summary":"clea
# ...

# %%
dn = pd.DataFrame(api_url.json())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 dn = pd.DataFrame(api_url.json())
#
# File D:\jupyter\mynumpy\lib\site-packages\pandas\core\frame.py:663, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     657     mgr = self._init_mgr(
#     658         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     659     )
#     661 elif isinstance(data, dict):
#     662     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 663     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     664 elif isinstance(data, ma.MaskedArray):
#     665     import numpy.ma.mrecords as mrecords
#
# File D:\jupyter\mynumpy\lib\site-packages\pandas\core\internals\construction.py:493, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     489     else:
# ...

# %%
dt.json()['results']

# %%
import pandas as pd
import requests

# %%
import requests

url = "https://iata-and-icao-codes.p.rapidapi.com/airlines"

headers = {
	"X-RapidAPI-Key": "7c97880d88msh385904ea8bbf2efp1265a2jsn984f1daf83a4",
	"X-RapidAPI-Host": "iata-and-icao-codes.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)

# %%
print(response.json())
# Out:
# [{'iata_code': '0V', 'name': 'VASCO', 'icao_code': 'VFC'}, {'iata_code': '1X', 'name': 'Branson Air Express', 'icao_code': None}, {'iata_code': '2G', 'name': 'Angara Airlines', 'icao_code': 'AGU'}, {'iata_code': '2I', 'name': 'Star Peru', 'icao_code': 'SRU'}, {'iata_code': '2J', 'name': 'Air Burkina', 'icao_code': 'VBW'}, {'iata_code': '2K', 'name': 'Avianca', 'icao_code': 'GLG'}, {'iata_code': '2M', 'name': 'Maya Island Air', 'icao_code': 'MYD'}, {'iata_code': '2B', 'name': 'Albawings', 'icao_code': 'AWT'}, {'iata_code': '0B', 'name': 'Blue Air', 'icao_code': 'BMS'}, {'iata_code': '2L', 'name': 'Helvetic Airways', 'icao_code': 'OAW'}, {'iata_code': '2U', 'name': "Sun d'Or Airlines", 'icao_code': 'ERO'}, {'iata_code': '2Z', 'name': 'Passaredo Linhas Aéreas', 'icao_code': 'PTB'}, {'iata_code': '3B', 'name': 'Binter Cabo Verde', 'icao_code': 'NTB'}, {'iata_code': '3C', 'name': 'Air Chathams', 'icao_code': 'CVA'}, {'iata_code': '3E', 'name': 'Air Choice One', 'icao_code': 'WBR'}, {'iata
# ...

# %%
df = pd.DataFrame(response.json())

# %%
df
# Out:
#     iata_code                 name icao_code
# 0          0V                VASCO       VFC
# 1          1X  Branson Air Express      None
# 2          2G      Angara Airlines       AGU
# 3          2I            Star Peru       SRU
# 4          2J          Air Burkina       VBW
# ..        ...                  ...       ...
# 751        5J         Cebu Pacific       CEB
# 752        NZ      Air New Zealand       ANZ
# 753        TR                Scoot       TGW
# 754        5K               Hi Fly       HFY
# 755        HG   Hibernian Airlines       HBN
#
# [756 rows x 3 columns]

# %%
import pandas as pd
import requests

# %%
dt = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
dt.json()

# %%
import pandas as pd

# %%
import requests

url = "https://weather1060.p.rapidapi.com/"

headers = {
	"X-RapidAPI-Key": "7c97880d88msh385904ea8bbf2efp1265a2jsn984f1daf83a4",
	"X-RapidAPI-Host": "weather1060.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)

print(response)
# Out:
# <Response [200]>

# %%
response
# Out:
# <Response [200]>

# %%
dt = pd.DataFrame(response)

# %%
dt
# Out:
#                                                       0
# 0     b'<!DOCTYPE html><html><head><meta charset="ut...
# 1     b'https://rapidapi.com"><title>Rapid - The Nex...
# 2     b'/favicons/apple-icon-57x57.png"><link rel="a...
# 3     b'l="apple-touch-icon" sizes="72x72" href="/as...
# 4     b'"/assets/favicons/apple-icon-76x76.png"><lin...
# ...                                                 ...
# 1309  b"contentWindow.document;if (_0xi) {var _0xj =...
# 1310  b"TagName('head')[0].appendChild(_0xj);}}if (d...
# 1311  b"cument.addEventListener('DOMContentLoaded', ...
# 1312  b"nreadystatechange = function (e) {prev(e);if...
# 1313                 b'};}})();</script></body></html>'
#
# [1314 rows x 1 columns]

# %%
import requests

# %%
ab = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
ab.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#    'genre_ids': [18, 80],
#    'id': 238,
#    'original_language': 'en',
#    'original_title': 'The Godfather',
#    'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#    'popularity': 105.902,
#    'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#    'release_date': '1972-03-14',
#    'title': 'The Godfather',
#    'video': False,
#    'vote_average': 8.7,
#    'vote_count': 17567},
#   {'adult': False,
#    'backdrop_path': '/wPU78OPN4BYEgWYdXyg0phMee64.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
# ...

# %%
temp_df = pd.DataFrame(ab.json()['results'])[['id','title','popularity','release_date','original_language']]

# %%
temp_df
# Out:
#         id                                          title  popularity  \
# 0      238                                  The Godfather     105.902
# 1      278                       The Shawshank Redemption      82.189
# 2   772071                               Cuando Sea Joven      37.191
# 3   995133       The Boy, the Mole, the Fox and the Horse      40.516
# 4      240                          The Godfather Part II      59.244
# 5      424                               Schindler's List      57.818
# 6    19404                    Dilwale Dulhania Le Jayenge      24.752
# 7      129                                  Spirited Away      78.307
# 8      389                                   12 Angry Men      32.077
# 9   372058                                     Your Name.      96.078
# 10  496243                                       Parasite      58.426
# 11     155                                The Dark Knight      85.004
# ...

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,501):
    ab = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(ab.json()['results'])[['id','title','popularity','release_date','original_language']]
    df.append(temp_df, ignore_index=True)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_13784\317171083.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(temp_df, ignore_index=True)
# C:\Users\PC\AppData\Local\Temp\ipykernel_13784\317171083.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(temp_df, ignore_index=True)
# C:\Users\PC\AppData\Local\Temp\ipykernel_13784\317171083.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(temp_df, ignore_index=True)
# C:\Users\PC\AppData\Local\Temp\ipykernel_13784\317171083.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(temp_df, ignore_index=True)
# ...

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.to_csv('')

# %%
import requests

# %%
import requests

url = "https://icd10.p.rapidapi.com/icd10/v1/liver+carcinoma"

headers = {
	"Authorization": "Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJodHRwOlwvXC9hcGkuaW9kb2pvLmNvbVwvdG9rZW4iLCJpYXQiOjE2Mzk0OTc0MjksIm5iZiI6MTYzOTQ5NzQyOSwianRpIjoiT3NXRnRoTlN2UnBkSXpqNyIsInN1YiI6MSwicHJ2IjoiODdlMGFmMWVmOWZkMTU4MTJmZGVjOTcxNTNhMTRlMGIwNDc1NDZhYSJ9.TbOkiefndtSZ2spS11fTeR8jPtVPv9UVKg7xrmueff0",
	"X-RapidAPI-Key": "7c97880d88msh385904ea8bbf2efp1265a2jsn984f1daf83a4",
	"X-RapidAPI-Host": "icd10.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {"current_page":1,"data":[{"code":"C22.0","name":"Liver cell carcinoma","description":"Hepatocellular carcinoma\r\nHepatoma\r\n","chapter":"II Neoplasms","block":"C00-D48 Malignant neoplasms of digestive organs","icd10_morphology":{"M8170\/3":"Hepatocellular carcinoma NOS (C22.0)","M8171\/3":"Hepatocellular carcinoma, fibrolamellar (C22.0)","M8180\/3":"Combined hepatocellular carcinoma and cholangiocarcinoma (C22.0)","M8970\/3":"Hepatoblastoma (C22.0)"}},{"code":"C22.7","name":"Other specified carcinomas of liver","description":null,"chapter":"II Neoplasms","block":"C00-D48 Malignant neoplasms of digestive organs"}],"first_page_url":"http:\/\/api.iodojo.com\/icd10\/v1\/liver+carcinoma?page=1","from":1,"last_page":1,"last_page_url":"http:\/\/api.iodojo.com\/icd10\/v1\/liver+carcinoma?page=1","next_page_url":null,"path":"http:\/\/api.iodojo.com\/icd10\/v1\/liver+carcinoma","per_page":10,"prev_page_url":null,"to":2,"total":2}

# %%
dn = pd.DataFrame(response.json()['data'])
dn
# Out:
#     code                                 name  \
# 0  C22.0                 Liver cell carcinoma
# 1  C22.7  Other specified carcinomas of liver
#
#                                 description       chapter  \
# 0  Hepatocellular carcinoma\r\nHepatoma\r\n  II Neoplasms
# 1                                      None  II Neoplasms
#
#                                              block  \
# 0  C00-D48 Malignant neoplasms of digestive organs
# 1  C00-D48 Malignant neoplasms of digestive organs
#
#                                     icd10_morphology
# 0  {'M8170/3': 'Hepatocellular carcinoma NOS (C22...
# 1                                                NaN

# %%
import requests
from bs4 import BeautifulSoup

# %%
import requests

url = "https://nigeria-covid.p.rapidapi.com/"

headers = {
	"X-RapidAPI-Key": "7c97880d88msh385904ea8bbf2efp1265a2jsn984f1daf83a4",
	"X-RapidAPI-Host": "nigeria-covid.p.rapidapi.com"
}

response = requests.request("POST", url, headers=headers)

print(response.text)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <meta charset="utf-8">
#     <title>Heroku | Application Error</title>
#     <style media="screen">
#       html,body,iframe {
#         margin: 0;
#         padding: 0;
#       }
#       html,body {
#         height: 100%;
#         overflow: hidden;
#       }
#       iframe {
#         width: 100%;
#         height: 100%;
#         border: 0;
#       }
#     </style>
#   </head>
#   <body>
#     <iframe src="//www.herokucdn.com/error-pages/no-such-app.html"></iframe>
#   </body>
# </html>

# %%
BeautifulSoup(response,'lxml')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 BeautifulSoup(response,'lxml')
#
# File D:\jupyter\mynumpy\lib\site-packages\bs4\__init__.py:313, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     311 if hasattr(markup, 'read'):        # It's a file-type object.
#     312     markup = markup.read()
# --> 313 elif len(markup) <= 256 and (
#     314         (isinstance(markup, bytes) and not b'<' in markup)
#     315         or (isinstance(markup, str) and not '<' in markup)
#     316 ):
#     317     # Issue warnings for a couple beginner problems
#     318     # involving passing non-markup to Beautiful Soup.
#     319     # Beautiful Soup will still parse the input as markup,
#     320     # since that is sometimes the intended behavior.
# ...

# %%
import pandas as pd
import requests
import warnings
warnings.filterwarnings('ignore')

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
#   'original_title': 'The Godfather',
#   'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#   'popularity': 107.242,
#   'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#   'release_date': '1972-03-14',
#   'title': 'The Godfather',
#   'video': False,
#   'vote_average': 8.7,
#   'vote_count': 17604},
#  {'adult': False,
#   'backdrop_path': '/wPU78OPN4BYEgWYdXyg0phMee64.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
# ...

# %%
response = pd.DataFrame(response.json())

# %%
response.head(6)
# Out:
#                                    errors  success
# 0  page must be less than or equal to 500    False

# %%
empty_df = pd.DataFrame()

# %%
for i in range(1,500):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','original_language','popularity','release_date','title','vote_average']]
    empty_df = empty_df.append(temp_df,ignore_index=True)

# %%
empty_df.to_csv('movies11.csv')

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#    'genre_ids': [18, 80],
#    'id': 238,
#    'original_language': 'en',
#    'original_title': 'The Godfather',
#    'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#    'popularity': 113.405,
#    'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#    'release_date': '1972-03-14',
#    'title': 'The Godfather',
#    'video': False,
#    'vote_average': 8.7,
#    'vote_count': 17613},
#   {'adult': False,
#    'backdrop_path': '/wPU78OPN4BYEgWYdXyg0phMee64.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
# ...

# %%
dg = pd.DataFrame(response.json()['results'])[['id','original_title','original_language','release_date']]

# %%
dg.head(6)
# Out:
#        id                original_title original_language release_date
# 0     238                 The Godfather                en   1972-03-14
# 1     278      The Shawshank Redemption                en   1994-09-23
# 2  772071              Cuando Sea Joven                es   2022-09-14
# 3     240         The Godfather Part II                en   1974-12-20
# 4     424              Schindler's List                en   1993-12-15
# 5   19404  दिलवाले दुल्हनिया ले जायेंगे                hi   1995-10-19

# %%
data_fetch = pd.DataFrame()

# %%
for i in range(1,501):
    da = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(da.json()['results'])[['id','original_title','original_language','release_date']]
    data_fetch =  data_fetch.append(temp_df, ignore_index=True)

# %%
data_fetch
# Out:
#           id                   original_title original_language release_date
# 0        238                    The Godfather                en   1972-03-14
# 1        278         The Shawshank Redemption                en   1994-09-23
# 2     772071                 Cuando Sea Joven                es   2022-09-14
# 3        240            The Godfather Part II                en   1974-12-20
# 4        424                 Schindler's List                en   1993-12-15
# ...      ...                              ...               ...          ...
# 9995   11817                 Bulletproof Monk                en   2003-03-28
# 9996   29564  Smokin' Aces 2: Assassins' Ball                en   2010-01-19
# 9997   14365                Killing Me Softly                en   2002-05-10
# 9998  230179                         Big Game                en   2014-09-05
# 9999   19366          Josie and the Pussycats                en   2001-04-06
#
# [10000 rows x 4 columns]

# %%
import numpy as np
import pandas as pd
import requests
import warnings
warnings.simplefilter("ignore")

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
dg = pd.DataFrame(response.json()['results'])

# %%
dg
# Out:
#     adult                     backdrop_path            genre_ids      id  \
# 0   False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg             [18, 80]     238
# 1   False  /wPU78OPN4BYEgWYdXyg0phMee64.jpg             [18, 80]     278
# 2   False  /ejniJnlOdtSgtbh8D7u2RxT6Uli.jpg             [35, 14]  772071
# 3   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg             [18, 80]     240
# 4   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg      [18, 36, 10752]     424
# 5   False  /vI3aUGTuRRdM7J78KIdW98LdxE5.jpg      [35, 18, 10749]   19404
# 6   False  /Ab8mkHmkYADjU7wQiOkia9BzGvS.jpg      [16, 10751, 14]     129
# 7   False  /tj6iPnz18hGfr0LKqWmG6Cp3niO.jpg                 [18]     389
# 8   False  /dIWwZW7dJJtqC6CgWzYkNVKIUm8.jpg      [10749, 16, 18]  372058
# 9   False  /wxaBkuqVIgImjRHEMJoxL9Lq6i8.jpg  [16, 10751, 12, 14]  995133
# 10  False  /hiKmpZMGZsrkA3cdce8a7Dpos1j.jpg         [35, 53, 18]  496243
# 11  False  /pbEkjhdfP7yuDcMB78YEZwgD4IN.jpg     [18, 28, 80, 53]     155
# ...

# %%
fetch_data = pd.DataFrame()

# %%
for i in range(1,501):
    resp = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    df = pd.DataFrame(resp.json()['results'])
    fetch_data = fetch_data.append(df, ignore_index=True)
